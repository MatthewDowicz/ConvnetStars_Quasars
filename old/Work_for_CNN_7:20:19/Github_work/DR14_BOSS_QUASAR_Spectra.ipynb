# %%
from astropy.io import fits
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#sns.set()

# %%
def reading_in(fits_name):
    fits_image_filename = fits.open("/Users/matt/Desktop/DESI_Research/DESI_ML/DR14_Q_Spectra/" + str(fits_name) +"")
    hdul = fits_image_filename 
    Q_data_coadd = hdul["COADD"].data
    Q_data_spa = hdul["SPALL"].data
    Q_data = [Q_data_coadd, Q_data_spa]
    
    return Q_data

def assignment(Q_data):
    flux = Q_data[0].field("flux")
    wave = Q_data[0].field("loglam")
    z = Q_data[1].field("Z")
    values = [wave, flux, z]
    
    return values

def plot(flux, wave, name):
    plt.figure(figsize=(14,8))
    plt.plot(flux, wave)
    plt.xlabel("wavelength [I don't know the units]")
    plt.ylabel("Flux [$10^{-17}$ erg/$cm^2$/s/$\AA$]")
    plt.grid()
    plt.title("" + str(name)+ "")
    
def total_func(fits_name):
    data = reading_in(fits_name)
    values = assignment(data)
    graph = plot(values[0],values[1], fits_name)
    
    return graph

def subplots(fits_list):
    for i in range(len(fits_list)):
        plots = total_func(fits_list[i])
        
    return plots

# %%
fits_list = ("spec-7596-56945-0162.fits", "spec-8740-57367-0694.fits", "spec-6177-56268-0595.fits", \
             "spec-4415-55831-0464.fits", "spec-7666-57339-0121.fits", "spec-4354-55810-0678.fits",\
            "spec-4354-55810-0646.fits", "spec-6110-56279-0086.fits", "spec-7595-56957-0273.fits",\
            "spec-7850-56956-0711.fits")

# %%
subplots(fits_list)

# %%
fits_image_totalQ = fits.open("/Users/matt/Desktop/DESI_Research/DESI_ML/DR14_Q_spectra/DR14Q_v4_4.fits")
hdul = fits_image_totalQ #hdul.info() 
#hdul.info() # entire fits file layout
quasar_data = Table(hdul["DR14Q_v4_4"].data) #quasar_data # specific data about single layer b
quasar_data

#quasar_data = hdul["DR14Q_v4_4"].data
#print(quasar_data["FIRST_SNR"])#
# Out:
# <Table length=526356>
#     SDSS_NAME                RA          ... FIRST_SNR SDSS2FIRST_SEP
#       str18               float64        ...  float64     float64
# ------------------ --------------------- ... --------- --------------
# 000000.45+174625.4  0.001898274356335605 ...      -1.0           -1.0
# 000000.57+055630.8 0.0023754761888312714 ...      -1.0           -1.0
# 000000.66+145828.8  0.002756432550313548 ...      -1.0           -1.0
# 000000.97+044947.2  0.004052389452795069 ...      -1.0           -1.0
# 000001.20+240354.5  0.005025713552072375 ...      -1.0           -1.0
# 000001.27-020159.7  0.005316971570891838 ...  7.048389        0.57105
# 000001.37-011930.0  0.005746209112004408 ...      -1.0           -1.0
# 000001.41+200044.1  0.005912092570781624 ...      -1.0           -1.0
# 000001.47+211636.1  0.006143972596646563 ...      -1.0           -1.0
# 000001.55-003332.6  0.006463516241467461 ...      -1.0           -1.0
# ...

# %%
#total_func("spec-7596-56945-0162.fits")

fits_image_totalQ = fits.open("/Users/matt/Desktop/DESI_Research/DESI_ML/DR14_Q_spectra/DR14Q_v4_4.fits")
hdul = fits_image_totalQ #hdul.info() # entire fits file layout
quasar_data = Table(hdul["DR14Q_v4_4"].data) #quasar_data # specific data about single layer b
quasar_data
"---------------------------"

fits_image_filename = fits.open("/Users/matt/Desktop/DESI_Research/DESI_ML/DR14_Q_spectra/spec-7596-56945-0162.fits")
hdul = fits_image_filename
Q_add_data1 = hdul["COADD"].data
Q_data_spa1 = hdul["SPALL"].data
Table(hdul["COADD"].data)
#Table(hdul["SPALL"].data)
# Out:
# <Table length=3510>
#     flux      loglam     ivar    and_mask ...   wdisp       sky      model
#   float32    float32   float32    int32   ...  float32    float32   float32
# ------------ ------- ----------- -------- ... ---------- --------- ----------
#   -15.404429  3.5522  0.04311254        0 ...   1.375745  6.264703  1.2609143
#   -6.2449727  3.5523         0.0        0 ...  1.3750303 5.8958178  1.2723542
#    2.9088907  3.5524   0.0505064        0 ...  1.3743246  5.565446   1.314909
#   -0.8889084  3.5525 0.056677543        0 ...  1.3736123  5.298763  1.3204244
#     6.210315  3.5526 0.060671147        0 ...  1.3729001  5.173511  1.3133472
#  -0.42623204  3.5527  0.06861566        0 ...   1.372191  5.010838  1.3465716
#  -0.17885284  3.5528  0.07807105        0 ...  1.3714862 4.8210154   1.394587
#   -2.3203685  3.5529  0.08200885        0 ...  1.3707824 4.6513324  1.3856062
#    7.4576154   3.553  0.06557226        0 ...  1.3700697 4.7170205  1.3355728
# ...

# %%
fits_image_filename = fits.open("/Users/matt/Desktop/DESI_Research/DESI_ML/DR14_Q_spectra/spec-7596-56945-0162.fits")
hdul = fits_image_filename
Q_add_data1 = Table(hdul["SPALL"].data)
Q_add_data1
# Out:
# <Table length=1>
# PROGRAMNAME CHUNK  PLATEQUALITY PLATESN2 ... NOBSERVE NDETECT NEDGE   SCORE
#    str27    str14      str4     float32  ...  int32    int32  int32  float32
# ----------- ------ ------------ -------- ... -------- ------- ----- ---------
#       eboss eboss1         good  16.5231 ...        1       1     0 0.8703802

# %% [markdown]
# ## Update:

# %% [markdown]
# For the units for the wavelength I tried exponentiating it because I read on the SDSS website that they were logged. That didn't produce the right values. I also tried to see if they had to be redshifted and that didn't produce the right values either. Lastly, I redshifted them and then converted to angstroms and that didn't work either, but I was able to get in the right order of magnitude. If you have any insight to the correct conversion that would be very helpful.

# %% [markdown]
# ## Next:

# %% [markdown]
# Lee helped me understand GitHub. We couldn't figure out how to clone the repository, but I was able to download it and will just use the CNN model and use their training set to train the model. Then I'll use the Quasars that you sent me as the test set, so I can get my feet-wet with CNN code.
